# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([41,85,98,73,69,89,98,89,39,56,100,99,84,42,83,100,45,64,97,92,57,29,48,39,96,100,41,70,88,96,96,39,64,85,93,100,98,76,43,49,45,99,88,37,62,100,84,68,79,99,67,42,98,90,35,71,100,68,66,98,96,55,44,80,100,99,95,82,48,42,73,49,100,93,69,48,32,49,30,48,75,85,100,99,72,32,48,100,87,70,43,62,100,99,95,79,50,43,69,100,91,66,31,52,86,99,100,98,76,29,49,44,64,100,99,73,33,51,97,99,64,60,99,84,41,80,87,99,65,31,48,76,85,91,34,51])

# %%
x.shape
print(np.sum(x) / x.shape)
# Out:
# [72.19117647]

# %%
y = np.arange(1, 137, 1, dtype=int)

# %%
plt.figure(figsize=(10, 5))
plt.plot(y, x)

# ax.grid()

# %%
plt.figure(figsize=(10, 5))
plt.plot(y, x)

# ax.grid()
plt.show()
