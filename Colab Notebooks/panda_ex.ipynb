# %%
import pandas as pd
import json

# %%
path = '/content/drive/MyDrive/Colab Notebooks/Project/noise-reducer-ml/Dataset/noisy.json'
with open(path) as f:
  data = json.load(f)
  print(data[1])
# Out:
# /content/test/Dataset/noisy/Copy of p287_002.wav

# %%
df
# Out:
# '"/content/drive/MyDrive/Colab Notebooks/Project/noise-reducer-ml/Dataset/noisy.json"'

# %%
df
# Out:
#                                                    0
# 0   /content/test/Dataset/noisy/Copy of p287_001.wav
# 1   /content/test/Dataset/noisy/Copy of p287_002.wav
# 2   /content/test/Dataset/noisy/Copy of p287_003.wav
# 3   /content/test/Dataset/noisy/Copy of p287_004.wav
# 4   /content/test/Dataset/noisy/Copy of p287_005.wav
# 5   /content/test/Dataset/noisy/Copy of p287_006.wav
# 6           /content/test/Dataset/noisy/p287_001.wav
# 7           /content/test/Dataset/noisy/p287_002.wav
# 8           /content/test/Dataset/noisy/p287_003.wav
# 9           /content/test/Dataset/noisy/p287_004.wav
# 10          /content/test/Dataset/noisy/p287_005.wav
# 11          /content/test/Dataset/noisy/p287_006.wav
