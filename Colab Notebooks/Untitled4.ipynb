# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content'
# !python3 enhance.py --model_path "/content/drive/MyDrive/BILSTM_checkpoint.h5" --noisy_path "/content/sample_data/tahil_vai.wav" --enhanced_path '/content/test.wav'
# Out:
# /content
# 2022-06-19 07:36:21.042509: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# tf.Tensor(
# [[-2.7879531e-04]
#  [ 1.6486627e-04]
#  [ 1.5419304e-04]
#  ...
#  [ 8.7925197e-05]
#  [ 4.9530892e-05]
#  [ 6.0212646e-05]], shape=(418223, 1), dtype=float32)
# 100.0
