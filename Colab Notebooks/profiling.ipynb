# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Project/diffq_nr/noise-reducer-ml/denoiser-inverse
# Out:
# /content/drive/MyDrive/Colab Notebooks/Project/diffq_nr/noise-reducer-ml/denoiser-inverse

# %%
# !python3 train_diffq.py
# Out:
# 2022-06-19 09:34:56.433787: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:tensorflow:There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# Number of GPUs we have: 1
# Created a new model
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring...
# Layer Con1DLayer has arguments ['self', 'in_c', 'out_c', 'kernel_size', 'stride', 'activation', 'padding']
# in `__init__` and therefore must override `get_config()`.
#
# Example:
#
# class CustomLayer(keras.layers.Layer):
#     def __init__(self, arg1, arg2):
#         super().__init__()
#         self.arg1 = arg1
#         self.arg2 = arg2
#
#     def get_config(self):
#         config = super().get_config()
#         config.update({
#             "arg1": self.arg1,
#             "arg2": self.arg2,
#         })
#         return config
# ...
