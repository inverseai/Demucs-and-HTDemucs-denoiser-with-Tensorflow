# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Project/noise-reducer-ml/denoiser-inverse
# !cp  '/content/drive/MyDrive/tfrecords/test-001-300.tfrecord' '/content/tfrecords/test.tfrecord'
# Out:
# /content/drive/MyDrive/Colab Notebooks/Project/noise-reducer-ml/denoiser-inverse

# %%
# !pip3 install pesq
# !python3 pesq_evaluation.py --model_path '/content/drive/MyDrive/checkpoint_epoch-035_loss-0.0029.h5' --noisy_path '/content/tfrecords'
# Out:
# 2022-04-20 09:44:11.557055: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# here
# <class 'tensorflow.python.data.ops.dataset_ops.PrefetchDataset'>
# <class 'keras.engine.functional.Functional'>
# 11
# 3.1580027558586816
