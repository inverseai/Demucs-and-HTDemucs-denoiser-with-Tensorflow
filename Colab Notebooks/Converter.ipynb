# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ^C

# %%
# !cp -R '/content/drive/MyDrive/Colab Notebooks/Project/noise-reducer-ml/Dataset' /content/test

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Project/noise-reducer-ml/denoiser-inverse/
# Out:
# /content/drive/MyDrive/Colab Notebooks/Project/noise-reducer-ml/denoiser-inverse

# %%
# !python3 convert.py -ni '/content/test/noisy.json' -ci '/content/test/clean.json' -o '/content/test/output' --num-shards-train 1 --num-shards-test 1 --num-shards-val 1 --duration 4 --sample-rate 48000 --test-size 0.2 --val-size 0.2
# Out:
# Splitting train set into TFRecord shards...
# [('/content/test/output/train-001-6.tfrecord', array([0, 1, 2, 3, 4, 5]))]
# Splitting test set into TFRecord shards...
# [('/content/test/output/train-001-6.tfrecord', array([0, 1, 2, 3, 4, 5])), ('/content/test/output/test-001-3.tfrecord', array([6, 7, 8]))]
# Splitting validate set into TFRecord shards...
# [('/content/test/output/train-001-6.tfrecord', array([0, 1, 2, 3, 4, 5])), ('/content/test/output/test-001-3.tfrecord', array([6, 7, 8])), ('/content/test/output/validate-001-3.tfrecord', array([ 9, 10, 11]))]
#   0% 0/3 [00:00<?, ?it/s]2022-04-06 03:41:23.029699: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-04-06 03:41:23.034159: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at whole_file_read_ops.cc:116 : NOT_FOUND: /content/test/Dataset/noisy/Copy of p287_001.wav; No such file or directory
# ...

# %%
rm -r *
